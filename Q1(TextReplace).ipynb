# %%
with open(r'example.txt','r') as file:
    fdata=file.read()
    fdata=fdata.replace('placement','screening')
with open(r'example.txt','w') as file:
    file.write(fdata)
print('Text replaced')
# Out:
# Text replaced
